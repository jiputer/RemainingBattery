# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# %% [markdown]
# ## Linear Model For Each Column Against Remaining Useful Life

# %%
df = pd.read_csv("Featurized_Data.csv", index_col= 0)

# %%
df
# Out:
#          Remaining Useful Life  initial discharge capacity  \
# Cell ID
# 0                     2.408240                    0.998070
# 1                     2.176091                    0.996846
# 2                     2.328380                    0.994805
# 3                     2.201397                    1.010965
# 4                     2.227887                    1.003802
# ...                        ...                         ...
# 103                   2.045323                    1.015911
# 104                   2.749736                    1.006956
# 105                   2.344392                    1.024897
# 106                   2.255273                    1.006640
# 107                   2.330414                    0.959768
#
#          final discharge capacity  discharge cap. slope  dis. cap. intercept  \
# Cell ID
# 0                        0.998511             -0.000070             1.002587
# 1                        0.977803             -0.000414             0.994996
# ...

# %% [markdown]
# # Regression Based On Remaining Useful Life

# %%
reg_capacity = linear_model.LinearRegression()
reg = []

for column in df:
    if(column != 'Remaining Useful Life'):
        reg.append(reg_capacity.fit(df[column].to_numpy().reshape(-1,1), df['Remaining Useful Life'].to_numpy().reshape(-1,1)))
        print( column , "Coefficients: \n", reg_capacity.coef_)
# Out:
# initial discharge capacity Coefficients:
#  [[-0.32982322]]
# final discharge capacity Coefficients:
#  [[1.07610845]]
# discharge cap. slope Coefficients:
#  [[204.01961834]]
# dis. cap. intercept Coefficients:
#  [[1.01021755]]
#  min. resistance Coefficients:
#  [[-90.92924313]]
# Delta resistance Coefficients:
#  [[198.26720286]]
# Delta_Variance Coefficients:
#  [[1.95127565]]

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_4d18f_row0_col0, #T_4d18f_row1_col1, #T_4d18f_row2_col2, #T_4d18f_row3_col3, #T_4d18f_row4_col4, #T_4d18f_row5_col5, #T_4d18f_row6_col6, #T_4d18f_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4d18f_row0_col1, #T_4d18f_row2_col6, #T_4d18f_row4_col5 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_4d18f_row0_col2 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_4d18f_row0_col3 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_4d18f_row0_col4, #T_4d18f_row1_col0 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_4d18f_row0_col5, #T_4d18f_row1_col7, #T_4d18f_row3_col4, #T_4d18f_row5_col0, #T_4d18f_row5_col2, #T_4d18f_row5_col3, #T_4d18f_row5_col6, #T_4d18f_row7_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4d18f_row0_col6 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_4d18f_row0_col7 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# ...

# %%
X = df.loc[:, 'initial discharge capacity':'Delta_Variance']
X['intercept'] = 1

vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif = vif[vif['Variable']!='intercept']
vif
# Out:
#                      Variable       VIF
# 0  initial discharge capacity  3.141947
# 1    final discharge capacity  1.240514
# 2        discharge cap. slope  1.865595
# 3         dis. cap. intercept  2.087657
# 4             min. resistance  1.647493
# 5            Delta resistance  1.314833
# 6              Delta_Variance  3.799496
