# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Linear Model For Each Column Against Remaining Useful Life

# %%
df = pd.read_csv("Featurized_Data.csv", index_col= 0)

# %%
df['Remaining Useful Life'] = np.log(df['Remaining Useful Life'])
train, test = train_test_split(df, test_size=0.3, random_state=40946397)
df
# Out:
#          Remaining Useful Life  initial discharge capacity  \
# Cell ID
# 0                     0.878896                    0.998070
# 1                     0.777530                    0.996846
# 2                     0.845173                    0.994805
# 3                     0.789092                    1.010965
# 4                     0.801053                    1.003802
# ...                        ...                         ...
# 103                   0.715556                    1.015911
# 104                   1.011505                    1.006956
# 105                   0.852026                    1.024897
# 106                   0.813271                    1.006640
# 107                   0.846046                    0.959768
#
#          final discharge capacity  discharge cap. slope  dis. cap. intercept  \
# Cell ID
# 0                        0.998511             -0.000070             1.002587
# 1                        0.977803             -0.000414             0.994996
# 2                        0.982924             -0.000206             0.992808
# 3                        1.002828             -0.000416             1.012733
# 4                        0.979888             -0.000574             1.004001
# ...                           ...                   ...                  ...
# 103                      0.979040             -0.001282             0.993675
# 104                      1.010626             -0.000049             1.013589
# 105                      1.001408             -0.000452             1.017684
# 106                      0.983928             -0.000431             1.006601
# 107                      0.941845             -0.000391             0.958600
#
#           min. resistance  Delta resistance  Delta_Variance
# Cell ID
# 0                0.015569          0.000053        0.000017
# 1                0.015582         -0.000102        0.000112
# 2                0.015720         -0.000008        0.000038
# 3                0.017880         -0.000254        0.000178
# 4                0.017069         -0.000221        0.000227
# ...                   ...               ...             ...
# 103              0.018572         -0.000542        0.000570
# 104              0.015938          0.000026        0.000002
# 105              0.017530         -0.000183        0.000156
# 106              0.014954         -0.000116        0.000127
# 107              0.017173         -0.000022        0.000096
#
# [108 rows x 8 columns]

# %% [markdown]
# # Correlation Chart

# %%
corr = train.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_68e67_row0_col0, #T_68e67_row1_col1, #T_68e67_row2_col2, #T_68e67_row3_col3, #T_68e67_row4_col4, #T_68e67_row5_col5, #T_68e67_row6_col6, #T_68e67_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_68e67_row0_col1, #T_68e67_row3_col2 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_68e67_row0_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_68e67_row0_col3 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_68e67_row0_col4 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_68e67_row0_col5, #T_68e67_row1_col7, #T_68e67_row3_col4, #T_68e67_row5_col0, #T_68e67_row5_col2, #T_68e67_row5_col3, #T_68e67_row5_col6, #T_68e67_row7_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_68e67_row0_col6 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_68e67_row0_col7 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_68e67_row1_col0, #T_68e67_row6_col1 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_68e67_row1_col2 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_68e67_row1_col3 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_68e67_row1_col4 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_68e67_row1_col5 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_68e67_row1_col6 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_68e67_row2_col0 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_68e67_row2_col1, #T_68e67_row7_col5 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_68e67_row2_col3, #T_68e67_row4_col7 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_68e67_row2_col4, #T_68e67_row7_col4 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_68e67_row2_col5 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_68e67_row2_col6, #T_68e67_row7_col0 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_68e67_row2_col7 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_68e67_row3_col0 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_68e67_row3_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_68e67_row3_col5 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_68e67_row3_col6, #T_68e67_row6_col3 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_68e67_row3_col7 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_68e67_row4_col0 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_68e67_row4_col1 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_68e67_row4_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_68e67_row4_col3 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_68e67_row4_col5 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_68e67_row4_col6 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_68e67_row5_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_68e67_row5_col4 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_68e67_row5_col7 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_68e67_row6_col0 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_68e67_row6_col2 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_68e67_row6_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_68e67_row6_col5 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_68e67_row6_col7 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_68e67_row7_col2 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_68e67_row7_col3 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_68e67_row7_col6 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# </style>
# <table id="T_68e67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68e67_level0_col0" class="col_heading level0 col0" >Remaining Useful Life</th>
#       <th id="T_68e67_level0_col1" class="col_heading level0 col1" >initial discharge capacity</th>
#       <th id="T_68e67_level0_col2" class="col_heading level0 col2" >final discharge capacity</th>
#       <th id="T_68e67_level0_col3" class="col_heading level0 col3" >discharge cap. slope</th>
#       <th id="T_68e67_level0_col4" class="col_heading level0 col4" >dis. cap. intercept</th>
#       <th id="T_68e67_level0_col5" class="col_heading level0 col5" > min. resistance</th>
#       <th id="T_68e67_level0_col6" class="col_heading level0 col6" >Delta resistance</th>
#       <th id="T_68e67_level0_col7" class="col_heading level0 col7" >Delta_Variance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68e67_level0_row0" class="row_heading level0 row0" >Remaining Useful Life</th>
#       <td id="T_68e67_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_68e67_row0_col1" class="data row0 col1" >0.011858</td>
#       <td id="T_68e67_row0_col2" class="data row0 col2" >0.318327</td>
#       <td id="T_68e67_row0_col3" class="data row0 col3" >0.665266</td>
#       <td id="T_68e67_row0_col4" class="data row0 col4" >0.242851</td>
#       <td id="T_68e67_row0_col5" class="data row0 col5" >-0.593625</td>
#       <td id="T_68e67_row0_col6" class="data row0 col6" >0.617867</td>
#       <td id="T_68e67_row0_col7" class="data row0 col7" >0.048140</td>
#     </tr>
#     <tr>
#       <th id="T_68e67_level0_row1" class="row_heading level0 row1" >initial discharge capacity</th>
#       <td id="T_68e67_row1_col0" class="data row1 col0" >0.011858</td>
#       <td id="T_68e67_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_68e67_row1_col2" class="data row1 col2" >0.087500</td>
#       <td id="T_68e67_row1_col3" class="data row1 col3" >-0.284581</td>
#       <td id="T_68e67_row1_col4" class="data row1 col4" >0.246343</td>
#       <td id="T_68e67_row1_col5" class="data row1 col5" >-0.060100</td>
#       <td id="T_68e67_row1_col6" class="data row1 col6" >-0.053700</td>
#       <td id="T_68e67_row1_col7" class="data row1 col7" >-0.706449</td>
#     </tr>
#     <tr>
#       <th id="T_68e67_level0_row2" class="row_heading level0 row2" >final discharge capacity</th>
#       <td id="T_68e67_row2_col0" class="data row2 col0" >0.318327</td>
#       <td id="T_68e67_row2_col1" class="data row2 col1" >0.087500</td>
#       <td id="T_68e67_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_68e67_row2_col3" class="data row2 col3" >0.312803</td>
#       <td id="T_68e67_row2_col4" class="data row2 col4" >0.220656</td>
#       <td id="T_68e67_row2_col5" class="data row2 col5" >-0.188493</td>
#       <td id="T_68e67_row2_col6" class="data row2 col6" >0.110917</td>
#       <td id="T_68e67_row2_col7" class="data row2 col7" >0.026901</td>
#     </tr>
#     <tr>
#       <th id="T_68e67_level0_row3" class="row_heading level0 row3" >discharge cap. slope</th>
#       <td id="T_68e67_row3_col0" class="data row3 col0" >0.665266</td>
#       <td id="T_68e67_row3_col1" class="data row3 col1" >-0.284581</td>
#       <td id="T_68e67_row3_col2" class="data row3 col2" >0.312803</td>
#       <td id="T_68e67_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_68e67_row3_col4" class="data row3 col4" >-0.230972</td>
#       <td id="T_68e67_row3_col5" class="data row3 col5" >-0.494928</td>
#       <td id="T_68e67_row3_col6" class="data row3 col6" >0.565382</td>
#       <td id="T_68e67_row3_col7" class="data row3 col7" >0.228506</td>
#     </tr>
#     <tr>
#       <th id="T_68e67_level0_row4" class="row_heading level0 row4" >dis. cap. intercept</th>
#       <td id="T_68e67_row4_col0" class="data row4 col0" >0.242851</td>
#       <td id="T_68e67_row4_col1" class="data row4 col1" >0.246343</td>
#       <td id="T_68e67_row4_col2" class="data row4 col2" >0.220656</td>
#       <td id="T_68e67_row4_col3" class="data row4 col3" >-0.230972</td>
#       <td id="T_68e67_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_68e67_row4_col5" class="data row4 col5" >-0.016884</td>
#       <td id="T_68e67_row4_col6" class="data row4 col6" >0.041051</td>
#       <td id="T_68e67_row4_col7" class="data row4 col7" >0.218526</td>
#     </tr>
#     <tr>
#       <th id="T_68e67_level0_row5" class="row_heading level0 row5" > min. resistance</th>
#       <td id="T_68e67_row5_col0" class="data row5 col0" >-0.593625</td>
#       <td id="T_68e67_row5_col1" class="data row5 col1" >-0.060100</td>

# %% [markdown]
# # Checking VIF (Variance Inflation Factor)

# %%
X = train.loc[:, 'initial discharge capacity':'Delta_Variance']
X['intercept'] = 1

vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif = vif[vif['Variable']!='intercept']
vif
# Out:
#                      Variable       VIF
# 0  initial discharge capacity  3.082075
# 1    final discharge capacity  1.315193
# 2        discharge cap. slope  2.706539
# 3         dis. cap. intercept  2.127706
# 4             min. resistance  1.694931
# 5            Delta resistance  1.747207
# 6              Delta_Variance  3.548467

# %% [markdown]
# We see signs of multicolinearity, thus we need to remove some variables. Specifically, dis cap intercept. It looks like it is correlated to final charge a lot.

# %%
X = train[["initial discharge capacity","discharge cap. slope", "final discharge capacity"," min. resistance","Delta resistance","Delta_Variance"]]
X['intercept'] = 1

vif2 = pd.DataFrame()
vif2["Variable"] = X.columns
vif2["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif2 = vif2[vif2['Variable']!='intercept']
vif2
# Out:
# /var/folders/yn/5pqqn3bx73nb7c3fzcvg6tl80000gn/T/ipykernel_15183/413140109.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['intercept'] = 1
#                      Variable       VIF
# 0  initial discharge capacity  2.190744
# 1        discharge cap. slope  2.084034
# 2    final discharge capacity  1.186093
# 3             min. resistance  1.595768
# 4            Delta resistance  1.645881
# 5              Delta_Variance  2.125960

# %% [markdown]
# VIF is lower now, removing the cap intercept lowers it.

# %% [markdown]
# # Linear Regression on these variables

# %%
reg_capacity = linear_model.LinearRegression()
train_X = train[["initial discharge capacity","discharge cap. slope", "final discharge capacity"," min. resistance","Delta resistance","Delta_Variance"]]
train_Y = train["Remaining Useful Life"]
test_X = test[["initial discharge capacity","discharge cap. slope", "final discharge capacity"," min. resistance","Delta resistance","Delta_Variance"]]
test_Y = test["Remaining Useful Life"]
fit = reg_capacity.fit(train_X,train_Y)

# %% [markdown]
# # Predict Values

# %%
pred = fit.predict(test_X)
print('coefficeints: ', fit.coef_)
print('intercepts: ', fit.intercept_)

mean_squared_error(pred, test_Y)
# Out:
# coefficeints:  [  0.59891502  72.81782194   0.11871115 -17.67851721  63.62749459
#    5.27610562]
# intercepts:  0.4485582413467493
# 0.0042375753111745865

# %%
r2_score(pred, test_Y)
# Out:
# 0.4124300031096777

# %% [markdown]
# Bad predictor since R2 is low.

# %% [markdown]
# # Trying to transform the data

# %%
from sklearn.preprocessing import power_transform, PowerTransformer

pt = PowerTransformer()
transform_fit = pt.fit(train_X.to_numpy().reshape(-1,1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [489], line 5
#       3 pt = PowerTransformer()
#       4 transform_fit = pt.fit(train_X.to_numpy().reshape(-1,1))
# ----> 5 fit(X, y=None)
#
# TypeError: 'LinearRegression' object is not callable
